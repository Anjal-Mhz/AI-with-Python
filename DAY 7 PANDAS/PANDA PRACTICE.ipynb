# %%
import pandas as pd

df=pd.read_csv('ayurvedic_dosha_dataset (1).csv')
print(df)
# Out:
#          Body Frame Type of Hair Color of Hair           Skin Complexion  \
# 0        Well Built          Dry          Grey  Soft,Sweating    Pinkish
# 1     Thin and Lean       Normal         Brown   Moist,Greasy       Dark
# 2        Well Built          Dry         Brown      Dry,Rough       Dark
# 3     Thin and Lean       Greasy         Brown  Soft,Sweating    Pinkish
# 4        Well Built       Normal         Black  Soft,Sweating    Pinkish
# ...             ...          ...           ...            ...        ...
# 4995     Well Built          Dry          Grey   Moist,Greasy    Pinkish
# 4996     Well Built       Normal         Black      Dry,Rough    Glowing
# 4997         Medium       Greasy         Brown   Moist,Greasy    Pinkish
# 4998         Medium       Greasy         Brown   Moist,Greasy    Pinkish
# 4999     Well Built       Normal         Black      Dry,Rough       Dark
#
#       Body Weight     Nails Size and Color of the Teeth  \
# ...

# %%
df.head(4)
# Out:
#       Body Frame Type of Hair Color of Hair           Skin Complexion  \
# 0     Well Built          Dry          Grey  Soft,Sweating    Pinkish
# 1  Thin and Lean       Normal         Brown   Moist,Greasy       Dark
# 2     Well Built          Dry         Brown      Dry,Rough       Dark
# 3  Thin and Lean       Greasy         Brown  Soft,Sweating    Pinkish
#
#    Body Weight     Nails Size and Color of the Teeth Pace of Performing Work  \
# 0  Underweight    Redish                 Large,White                    Fast
# 1   Overweight  Blackish            Medium,Yellowish                  Medium
# 2  Underweight   Pinkish            Medium,Yellowish                    Fast
# 3   Overweight   Pinkish          Irregular,Blackish                    Slow
#
#   Mental Activity  ...            Hunger  Body Temperature Joints  \
# 0      Aggressive  ...        Skips Meal  Less than Normal   Weak
# 1      Aggressive  ...  Sudden and Sharp            Normal  Heavy
# ...

# %%
df.tail(4)
# Out:
#       Body Frame Type of Hair Color of Hair          Skin Complexion  \
# 4996  Well Built       Normal         Black     Dry,Rough    Glowing
# 4997      Medium       Greasy         Brown  Moist,Greasy    Pinkish
# 4998      Medium       Greasy         Brown  Moist,Greasy    Pinkish
# 4999  Well Built       Normal         Black     Dry,Rough       Dark
#
#       Body Weight     Nails Size and Color of the Teeth  \
# 4996   Overweight    Redish          Irregular,Blackish
# 4997   Overweight    Redish          Irregular,Blackish
# 4998  Underweight  Blackish                 Large,White
# 4999       Normal  Blackish            Medium,Yellowish
#
#      Pace of Performing Work Mental Activity  ...            Hunger  \
# 4996                  Medium          Stable  ...        Skips Meal
# 4997                    Fast      Aggressive  ...        Skips Meal
# 4998                  Medium      Aggressive  ...  Sudden and Sharp
# ...

# %%
df.describe()
# Out:
#        Body Frame Type of Hair Color of Hair       Skin Complexion  \
# count        5000         5000          5000       5000       5000
# unique          3            3             3          3          3
# top        Medium       Normal         Black  Dry,Rough    Glowing
# freq         1711         1706          1697       1681       1715
#
#        Body Weight     Nails Size and Color of the Teeth  \
# count         5000      5000                        5000
# unique           3         3                           3
# top         Normal  Blackish                 Large,White
# freq          1687      1679                        1684
#
#        Pace of Performing Work Mental Activity  ...     Hunger  \
# count                     5000            5000  ...       5000
# unique                       3               3  ...          3
# top                       Slow        Restless  ...  Irregular
# freq                      1702            1699  ...       1720
#
# ...

# %%
df.describe().T #Transpose like in matrix
# Out:
#                                   count unique                top  freq
# Body Frame                         5000      3             Medium  1711
# Type of Hair                       5000      3             Normal  1706
# Color of Hair                      5000      3              Black  1697
# Skin                               5000      3          Dry,Rough  1681
# Complexion                         5000      3            Glowing  1715
# Body Weight                        5000      3             Normal  1687
# Nails                              5000      3           Blackish  1679
# Size and Color of the Teeth        5000      3        Large,White  1684
# Pace of Performing Work            5000      3               Slow  1702
# Mental Activity                    5000      3           Restless  1699
# Memory                             5000      3          Long Term  1705
# Sleep Pattern                      5000      3             Sleepy  1720
# ...

# %%
print(df.shape)
print(df.shape[0])
print(df.shape[1])
# Out:
# (5000, 26)
# 5000
# 26

# %%
df.columns
# Out:
# Index(['Body Frame', 'Type of Hair', 'Color of Hair', 'Skin', 'Complexion',
#        'Body Weight', 'Nails', 'Size and Color of the Teeth',
#        'Pace of Performing Work', 'Mental Activity', 'Memory', 'Sleep Pattern',
#        'Weather Conditions', 'Reaction under Adverse Situations', 'Mood',
#        'Eating Habit', 'Hunger', 'Body Temperature', 'Joints', 'Nature',
#        'Body Energy', 'Quality of Voice', 'Dreams', 'Social Relations',
#        'Body Odor', 'Dosha'],
#       dtype='object')

# %%
list(df.columns)
# Out:
# ['Body Frame',
#  'Type of Hair',
#  'Color of Hair',
#  'Skin',
#  'Complexion',
#  'Body Weight',
#  'Nails',
#  'Size and Color of the Teeth',
#  'Pace of Performing Work',
#  'Mental Activity',
#  'Memory',
#  'Sleep Pattern',
#  'Weather Conditions',
#  'Reaction under Adverse Situations',
#  'Mood',
#  'Eating Habit',
#  'Hunger',
#  'Body Temperature',
#  'Joints',
#  'Nature',
#  'Body Energy',
#  'Quality of Voice',
#  'Dreams',
#  'Social Relations',
#  'Body Odor',
#  'Dosha']

# %%
df.isnull().head(2) #Checking first 2 data null or not
# Out:
#    Body Frame  Type of Hair  Color of Hair   Skin  Complexion  Body Weight  \
# 0       False         False          False  False       False        False
# 1       False         False          False  False       False        False
#
#    Nails  Size and Color of the Teeth  Pace of Performing Work  \
# 0  False                        False                    False
# 1  False                        False                    False
#
#    Mental Activity  ...  Hunger  Body Temperature  Joints  Nature  \
# 0            False  ...   False             False   False   False
# 1            False  ...   False             False   False   False
#
#    Body Energy  Quality of Voice  Dreams  Social Relations  Body Odor  Dosha
# 0        False             False   False             False      False  False
# 1        False             False   False             False      False  False
#
# [2 rows x 26 columns]

# %%
df.isnull().sum() #Sum of all null values in each coloumn
# Out:
# Body Frame                           0
# Type of Hair                         0
# Color of Hair                        0
# Skin                                 0
# Complexion                           0
# Body Weight                          0
# Nails                                0
# Size and Color of the Teeth          0
# Pace of Performing Work              0
# Mental Activity                      0
# Memory                               0
# Sleep Pattern                        0
# Weather Conditions                   0
# Reaction under Adverse Situations    0
# Mood                                 0
# Eating Habit                         0
# Hunger                               0
# Body Temperature                     0
# Joints                               0
# Nature                               0
# Body Energy                          0
# Quality of Voice                     0
# Dreams                               0
# Social Relations                     0
# ...

# %%
df.loc[[100,200]]
# Out:
#     Body Frame Type of Hair Color of Hair       Skin Complexion  Body Weight  \
# 100     Medium          Dry         Brown  Dry,Rough       Dark  Underweight
# 200     Medium          Dry         Black  Dry,Rough    Glowing       Normal
#
#         Nails Size and Color of the Teeth Pace of Performing Work  \
# 100   Pinkish          Irregular,Blackish                  Medium
# 200  Blackish          Irregular,Blackish                  Medium
#
#     Mental Activity  ...            Hunger  Body Temperature   Joints  \
# 100          Stable  ...        Skips Meal  More than Normal  Healthy
# 200          Stable  ...  Sudden and Sharp            Normal    Heavy
#
#                 Nature Body Energy Quality of Voice Dreams Social Relations  \
# 100  Egoistic,Fearless      Medium             Fast    Sky         Ambivert
# 200  Egoistic,Fearless         Low             Deep   Fire        Introvert
#
#       Body Odor  Dosha
# 100      Strong  Pitta
# 200  Negligible  Kapha
#
# ...

# %%
df.loc[[10,33],['Body Frame','Type of Hair','Skin']] #label based indexing
# Out:
#     Body Frame Type of Hair       Skin
# 10      Medium          Dry  Dry,Rough
# 33  Well Built          Dry  Dry,Rough
